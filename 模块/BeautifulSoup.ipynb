# %%
from bs4 import BeautifulSoup
import requests
import urllib.request
res = requests.get('http://news.sina.com.cn/china/')
res.encoding = 'utf-8'
ht = BeautifulSoup(res.text)
#print(ht)
# Out:
# /usr/local/lib/python3.5/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /usr/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
from bs4 import BeautifulSoup
import requests

html = 'http://read.qidian.com/chapter/-D24smocjMtcXB4XKBaZpQ2/PODWMJz5IMzM5j8_3RRvhw2'
res = requests.get(html)
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text, 'html.parser')
name = soup.find_all('h1')
read = soup.select("div.read-content.j_readContent")
filename = name[0].text
#print(filename)
print(read[0])
# Out:
# <div class="read-content j_readContent">
# ...

# %%
from bs4 import BeautifulSoup
import requests
import urllib.request
res2 = urllib.request.urlopen('http://news.sina.com.cn/china/').read().decode('utf-8')
ht2 = BeautifulSoup(res2)
print(ht2)
# Out:
# <!DOCTYPE html>
# <!-- [ published at 2016-12-09 17:45:21 ] --><html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <title>国内新闻_新闻中心_新浪网</title>
# <meta content="国内时政,内地新闻" name="keywords"/>
# <meta content="新闻中心国内频道，纵览国内时政、综述评论及图片的栏目，主要包括时政要闻、内地新闻、港澳台新闻、媒体聚焦、评论分析。" name="description"/>
# <meta content="noarchive" name="robots"/>
# <meta content="noarchive" name="Baiduspider"/>
# <meta content="no-transform" http-equiv="Cache-Control"/>
# <meta content="no-siteapp" http-equiv="Cache-Control"/>
# <meta content="pc,mobile" name="applicable-device"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <link color="red" href="http://www.sina.com.cn/favicon.svg" rel="mask-icon" sizes="any"/>
# <link href="http://news.sina.com.cn/css/87/20140115/gn2014/index.css" rel="stylesheet" type="text/css"/>
# <script src="http://i1.sinaimg.cn/home/sinaflash.js" type="text/javascript"></script>
# ...

# %%
from bs4 import BeautifulSoup
html = '\
<html> \
<body> \
<h1 id="title">hello world1</h1> \
<a href="#" class="link">this is link1</a> \
<a href="#" class="link">this is link2</a> \
<a href="#" class="link">this is link3</a> \
</body> \
</html>'

soup = BeautifulSoup(html, 'html.parser')
print(soup.a)#找出含有a标签的元素，同上（只返回第一个匹配的元素，如果想找出所有，必须要用select或find_all）
header = soup.select('a')#使用select找出含有a标签下的所有元素
print(header)
print(soup.h1)
print(soup.find_all('h1'))
print(soup.a.text)
print(soup.text)
print(header[0])
print(header[0].text)
# Out:
# <a class="link" href="#">this is link1</a>
# [<a class="link" href="#">this is link1</a>, <a class="link" href="#">this is link2</a>, <a class="link" href="#">this is link3</a>]
# <h1 id="title">hello world1</h1>
# [<h1 id="title">hello world1</h1>]
# this is link1
#   hello world1 this is link1 this is link2 this is link3
# <a class="link" href="#">this is link1</a>
# this is link1

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('http://news.sina.com.cn/china')
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text, 'html.parser')
#print(soup)

for news in soup.select('.news-item'):
    if len(news.select('h2')) > 0:#遍历出来，有些是空的，所以判断，空的不需要显示出来
        h2 = (news.find('a').text)#练习证明find比select更方便，select后，还需[0]把列表去掉，而它直接找出
        #h2 = (news.select('h2')[0])
        h2 = (news.select('h2')[0].text)
        #print(h2)
        a = news.find('a')['href']
        #print(a)
        time = news.select('.time')[0].text
        #print(time)
        print(time, h2, a)
# Out:
# 12月16日 13:58 河北宁晋破获跨国拐卖妇女案 解救5名越南女子 http://news.sina.com.cn/c/2016-12-16/doc-ifxytqqn8738013.shtml
# 12月16日 13:47 辉山乳业遭浑水公司做空 快速下跌后紧急停牌 http://news.sina.com.cn/o/2016-12-16/doc-ifxytkcf7844209.shtml
# 12月16日 13:42 北京雾霾南北差异巨大 或在夜间扩散至全市 http://news.sina.com.cn/c/nd/2016-12-16/doc-ifxytqqn8736499.shtml
# 12月16日 13:37 郑水泉任中国人民大学副书记 刘元春任副校长 http://news.sina.com.cn/c/nd/2016-12-16/doc-ifxytqqn8736154.shtml
# 12月16日 13:05 11月全国发生46起房屋市政工程事故 54人死亡 http://news.sina.com.cn/o/2016-12-16/doc-ifxytqqn8734300.shtml
# 12月16日 11:49 香港迪士尼成人票价涨至589港元 连续4年加价 http://news.sina.com.cn/o/2016-12-16/doc-ifxytkcf7835050.shtml
# 12月16日 10:57 北京市委巡视组将进驻38家单位 http://news.sina.com.cn/c/nd/2016-12-16/doc-ifxytkcf7828970.shtml
# 12月16日 10:29 国民党高层忧心智库遭台当局追杀 2名高管请辞 http://news.sina.com.cn/o/2016-12-16/doc-ifxytkcf7825329.shtml
# 12月16日 10:24 教育部公布研考违规违法举报电话 称绝不姑息 http://news.sina.com.cn/o/2016-12-16/doc-ifxytkcf7824822.shtml
# ...

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('http://news.sina.com.cn/china')
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text, 'html.parser')
#print(soup)

for news2 in soup.select('.ul01'):
    bb = news2.find('li').text
    aa = news2.find('a')['href']
    print(bb, aa)
# Out:
# “下狗屎也要做操”的媚权嘴脸很丑恶 http://news.sina.com.cn/zl/2016-06-02/doc-ifxsvenv6351703.shtml
# 社评:人大释法是香港法制完善的重大步骤 http://news.sina.com.cn/c/2016-11-05/doc-ifxxnffr6812344.shtml
# 习近平访问厄瓜多尔、秘鲁、智利 http://news.sina.com.cn/z/xjpfnmz3g

# %%
#想爬点击排行那里
import requests
from bs4 import BeautifulSoup
res = requests.get('http://news.sina.com.cn/china')
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text, 'html.parser')
#print(soup)

for news3 in soup.select('div', {'id':'subShowContent2_static'}):
    #bbb = news3.select('script')
    a1 = news3.find('a')
    #print(aaaa)
    print(a1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-152-7243a600b129> in <module>()
#       7 #print(soup)
#       8
# ----> 9 for news3 in soup.select('div', {'id':'subShowContent2_static'}):
#      10     #bbb = news3.select('script')
#      11     a1 = news3.find('a')
#
# /usr/local/lib/python3.5/dist-packages/bs4/element.py in select(self, selector, _candidate_generator, limit)
#    1516                     print("    Running candidate generator on %s %s" % (
#    1517                         tag.name, repr(tag.attrs)))
# -> 1518                 for candidate in _use_candidate_generator(tag):
#    1519                     if not isinstance(candidate, Tag):
#    1520                         continue
#
# TypeError: 'dict' object is not callable

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('http://news.qq.com/zt2015/wxghz/index.htm')
res.encoding = 'gb2312'
soup = BeautifulSoup(res.text, 'html.parser')
for news in soup.select('.nrC'):
    time = news.select('.time')[0].text
    title = news.select('.title')[0].text
    aa = 'http://news.qq.com'
    a = aa + news.select('a')[0]['href']
    print(time,title,a)
    #有个缺点，只是爬当前界面
# Out:
# 2016-12-21 河南400多名学生雾霾天在操场考试 校长称雾霾不严重 你一起呗？ http://news.qq.com/a/20161221/020992.htm
# 2016-12-19 老师称学生买自己的书考试能加分，太不要脸了吧 http://news.qq.com/a/20161219/021957.htm
# 2016-12-18 女子打麻将嫌吵，竟把3岁儿子锁狗笼，是亲生的吗？ http://news.qq.com/a/20161218/014816.htm
# 2016-12-17 男生不肯剪长发3月未上学 称头发是灵魂，这…… http://news.qq.com/a/20161217/017682.htm
# 2016-12-16 男子让女儿往车窗外丢吃完的泡面反被洒一脸，哈哈哈大快人心！ http://news.qq.com/a/20161216/022426.htm
# 2016-12-15 男子与公车司机起口角，扬言“不单挑我是你爹”后被揍翻。很行！ http://news.qq.com/a/20161215/022791.htm

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
html = urlopen('http://pythonscraping.com/pages/warandpeace.html')
obj = BeautifulSoup(html, 'lxml')
obj1 = obj.find_all('span', {'class':'green'})
#因为内容不多，即使不加span标签也能找出：
#obj.find_all({'class':'green'})或obj.find_all(class_='green')因为class是保留字，所以要么加{}要么class_
#print(obj1)
for name in obj1:
    print(name.get_text())
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %%
obj2 = obj.find_all('span', {'class':{'green','red'}})#返回两种颜色的span标签
obj2
# Out:
# [<span class="red">Well, Prince, so Genoa and Lucca are now just family estates of the
#  Buonapartes. But I warn you, if you don't tell me that this means war,
#  if you still try to defend the infamies and horrors perpetrated by
#  that Antichrist- I really believe he is Antichrist- I will have
#  nothing more to do with you and you are no longer my friend, no longer
#  my 'faithful slave,' as you call yourself! But how do you do? I see
#  I have frightened you- sit down and tell me all the news.</span>,
#  <span class="green">Anna
#  Pavlovna Scherer</span>,
#  <span class="green">Empress Marya
#  Fedorovna</span>,
#  <span class="green">Prince Vasili Kuragin</span>,
#  <span class="green">Anna Pavlovna</span>,
#  <span class="green">St. Petersburg</span>,
#  <span class="red">If you have nothing better to do, Count [or Prince], and if the
#  prospect of spending an evening with a poor invalid is not too
#  terrible, I shall be very charmed to see you tonight between 7 and 10-
# ...

# %%
#属性参数是用一个字典封装一个标签的若干属性和对应的属性值
print(obj.find_all({'h1','h2'}))
print('--------------------------------')
print(obj.find_all('span', {'class':{'green','red'}}))
# Out:
# [<h1>War and Peace</h1>, <h2>Chapter 1</h2>]
# --------------------------------
# [<span class="red">Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news.</span>, <span class="green">Anna
# Pavlovna Scherer</span>, <span class="green">Empress Marya
# Fedorovna</span>, <span class="green">Prince Vasili Kuragin</span>, <span class="green">Anna Pavlovna</span>, <span class="green">St. Petersburg</span>, <span class="red">If you have nothing better to do, Count [or Prince], and if the
# prospect of spending an evening with a poor invalid is not too
# ...

# %%
print(obj.find_all(text='the prince'))
print(obj.find(text='the prince'))
# Out:
# ['the prince', 'the prince', 'the prince', 'the prince', 'the prince', 'the prince', 'the prince']
# the prince

# %%
print(obj.find_all('h1', limit=1))#limit限制了次数，如果改动次数就显示几次#print(obj.find_all('p', limit=1))
print(obj.find('h1'))
#以上例子是等价的
#唯一的区别是 find_all() 方法的返回结果是值包含一个元素的列表,而 find() 方法直接返回结果.
#find_all() 方法没有找到目标是返回空列表, find() 方法找不到目标时,返回 None .
print('------------------------')
print(obj.find_all('h9', limit=1))
print(obj.find('h9'))
# Out:
# [<h1>War and Peace</h1>]
# <h1>War and Peace</h1>
# ------------------------
# []
# None

# %%
#print(obj.find_all(id='text')[0].get_text())

# %%
#关键字注意事项，以下是等价的
#obj.find_all(id='text')
#obj.find_all('', {'id':'text'})

print(obj.find_all(class_='green'))#class是Python保留关键字，如果确实需要用class，可以在后面加上_，或用第二种方法
print('-----------------------------------------')
print(obj.find_all('', {'class':'green'}))
# Out:
# [<span class="green">Anna
# Pavlovna Scherer</span>, <span class="green">Empress Marya
# ...

# %%
html = urlopen('http://pythonscraping.com/pages/page3.html')
bs0bj = BeautifulSoup(html, 'lxml')
print(len(list(bs0bj.find('table', {'id':'giftList'}).children)))
print('---------------------')
print(len(list(bs0bj.find('table', {'id':'giftList'}).descendants)))
# Out:
# 13
# ---------------------
# 86

# %%
html = urlopen('http://pythonscraping.com/pages/page3.html')
bs0bj = BeautifulSoup(html, 'lxml')
print(bs0bj.div.find_all('img'))
for child in bs0bj.find('table', {'id':'giftList'}).descendants:
    print(child)
# Out:
# [<img src="../img/gifts/logo.jpg" style="float:left;"/>, <img src="../img/gifts/img1.jpg"/>, <img src="../img/gifts/img2.jpg"/>, <img src="../img/gifts/img3.jpg"/>, <img src="../img/gifts/img4.jpg"/>, <img src="../img/gifts/img6.jpg"/>]
#
#
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
# <th>
# Item Title
# </th>
#
# Item Title
#
# <th>
# Description
# </th>
#
# Description
#
# <th>
# Cost
# </th>
#
# Cost
#
# <th>
# Image
# </th>
#
# Image
#
#
#
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
# <td>
# Vegetable Basket
# </td>
#
# Vegetable Basket
#
# <td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# ...

# %%
html = urlopen('http://pythonscraping.com/pages/page3.html')
bs0bj = BeautifulSoup(html, 'lxml')
for child in bs0bj.find('table', {'id':'giftList'}).descendants:
    print(child)
# Out:
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
# <th>
# Item Title
# </th>
#
# Item Title
#
# <th>
# Description
# </th>
#
# Description
#
# <th>
# Cost
# </th>
#
# Cost
#
# <th>
# Image
# </th>
#
# Image
#
#
#
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
# <td>
# Vegetable Basket
# </td>
#
# Vegetable Basket
#
# <td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td>
#
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
#
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# ...

# %%
from bs4 import BeautifulSoup
import requests
import urllib.request
html = urllib.request.urlopen('http://baike.baidu.com/view/284853.htm').read().decode('utf-8')
for h in html:
    
print(html)
# Out:
# <!DOCTYPE html>
# <!--STATUS OK-->
# <html>
#
#
#
# <head>
# <meta charset="UTF-8">
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="referrer" content="always" />
# <meta name="description" content="网络爬虫（又被称为网页蜘蛛，网络机器人，在FOAF社区中间，更经常的称为网页追逐者），是一种按照一定的规则，自动地抓取万维网信息的程序或者脚本。另外一些不常使用的名字还有蚂蚁、自动索引、模拟程序或者蠕虫。...">
# <title>网络爬虫_百度百科</title>
# <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />
# <link rel="icon" sizes="any" mask href="//www.baidu.com/img/baidu.svg">
#
# <meta name="keywords" content="网络爬虫 网页蜘蛛 爬虫程序 蜘蛛程序 搜索引擎蜘蛛 蜘蛛 网络蜘蛛 网络爬虫产生背景 网络爬虫面临的问题 网络爬虫分类 网络爬虫抓取目标的描述和定义 网络爬虫网页搜索策略 网络爬虫网页分析算法 网络爬虫补充">
# <meta name="image" content="http://baike.bdimg.com/cms/static/baike.png">
# <script type="text/javascript">
#   // 配置 PD 监控。
#   window.alogObjectConfig = {
#     product: '103',
#     page: '103_',
#     monkey_page: '',
#     speed_page: '',
#     speed: {
#       sample: '1'
#     },
#     monkey: {
#       sample: '1',
#       hid: '1533'
# ...

# %%
import urllib.request
import re
from bs4 import BeautifulSoup

def main():
    url = "http://baike.baidu.com/view/284853.htm"
    response = urllib.request.urlopen(url)
    html = response.read()
    soup = BeautifulSoup(html, "html.parser") # 使用 Python 默认的解析器
    
    for each in soup.find_all(href=re.compile("view")):
        print(each.text, "->", ''.join(["http://baike.baidu.com", each["href"]]))
        # 上边用 join() 不用 + 直接拼接，是因为 join() 被证明执行效率要高很多

if __name__ == "__main__":
    main()
# Out:
# 锁定 -> http://baike.baidu.com/view/10812319.htm
# 网络爬虫 -> http://baike.baidu.com/view/284853.htm
# 蜘蛛 -> http://baike.baidu.com/subview/8483/5395928.htm
# FOAF -> http://baike.baidu.com/view/271451.htm
# 万维网 -> http://baike.baidu.com/view/7833.htm
# 蚂蚁 -> http://baike.baidu.com/subview/3312/6169348.htm
# 蠕虫 -> http://baike.baidu.com/view/2596.htm
# 万维网 -> http://baike.baidu.com/view/7833.htm
# 网络 -> http://baike.baidu.com/view/3487.htm
# 万维网 -> http://baike.baidu.com/view/7833.htm
# 搜索引擎 -> http://baike.baidu.com/view/1154.htm
# 通用搜索引擎 -> http://baike.baidu.com/view/3107065.htm
# 网络数据 -> http://baike.baidu.com/view/727321.htm
# 万维网 -> http://baike.baidu.com/view/7833.htm
# 网络技术 -> http://baike.baidu.com/view/25363.htm
# 通用搜索引擎 -> http://baike.baidu.com/view/3107065.htm
# 关键字 -> http://baike.baidu.com/view/390935.htm
# 万维网 -> http://baike.baidu.com/view/7833.htm
# 搜索引擎 -> http://baike.baidu.com/view/1154.htm
# 排序算法 -> http://baike.baidu.com/view/297739.htm
# ...

# %%
import urllib.request
from bs4 import BeautifulSoup
import re
url = 'http://bbs.tianya.cn/post-stocks-1643256-1.shtml'
response = urllib.request.urlopen(url)
html = response.read()
soup = BeautifulSoup(html, "html.parser").get_text()
#re.match(('\\uu3000[\S\s]+?)\r\n', soup)
soup

#\uu3000开始
#\r\n结束
# Out:
# '\n\n\n\n\n短线牛股_股市论谈_天涯论坛\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\nvar bbsGlobal = {\r\n\tisEhomeItem : false,\r\n\tisNewArticle : false,\r\n\tauthorId : "107144256",\r\n\tauthorName : "向往441571207", \r\n\tblocktype : "主版",\r\n\titemType : "主版",\r\n\tlaibaType : "null",  \r\n\tpage : "1",\r\n\tpermission : true,\r\n\tpermissionStatus : "新用户发表审核",\r\n\titemPermission : 4161,\r\n\titemCategory : "财经",\r\n\tisWeiLun : false,\r\n\tisSealItem : false,\r\n\titem : "stocks",\r\n\titemName : "股市论谈",\r\n\tartId : 1643256,\r\n\tmedia : 1,\r\n\tsubType : "",\r\n\tad : 0,\r\n\tadshow : 0,\r\n\tadblock : 0,\r\n\twords : [{"link":"http://book.tianya.cn/chapter-81484","word":"爱情"},{"link":"http://book.tianya.cn/chapter-78815","word":"网约车"},{"link":"http://book.tianya.cn/chapter-81489","word":"女友"}],\r\n\tpageCount : 101,\r\n\tdashang : {\r\n\t\tmerId : "%E5%A4%A9%E6%B6%AF%E8%AE%BA%E5%9D%9B",\r\n\t\tmerNum : "stocks-1643256",\r\n\t\tgetName : "%E5%90%91%E5%BE%80441571207",\r\n\t\ttime : "1482110611294",
# ...

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('http://www.dmoz.org/Computers/Programming/Languages/Python/Books/')
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text, 'html.parser')
#print(soup)
for site in soup.select('#site-list-content'):
    title = site.find('target')
    print(title)


'''
for news in soup.select('.news-item'):
    if len(news.select('h2')) > 0:#遍历出来，有些是空的，所以判断，空的不需要显示出来
        h2 = (news.find('a').text)#练习证明find比select更方便，select后，还需[0]把列表去掉，而它直接找出
        #h2 = (news.select('h2')[0])
        h2 = (news.select('h2')[0].text)
        #print(h2)
        a = news.find('a')['href']
        #print(a)
        time = news.select('.time')[0].text
        #print(time)
        print(time, h2, a)
'''
# Out:
# None
# "\nfor news in soup.select('.news-item'):\n    if len(news.select('h2')) > 0:#遍历出来，有些是空的，所以判断，空的不需要显示出来\n        h2 = (news.find('a').text)#练习证明find比select更方便，select后，还需[0]把列表去掉，而它直接找出\n        #h2 = (news.select('h2')[0])\n        h2 = (news.select('h2')[0].text)\n        #print(h2)\n        a = news.find('a')['href']\n        #print(a)\n        time = news.select('.time')[0].text\n        #print(time)\n        print(time, h2, a)\n"

# %%
from bs4 import BeautifulSoup
import requests
import re

html = 'https://www.zhihu.com/search?type=topic&q=python'
headers = {'user-agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36'}
res = requests.get(html, headers = headers)
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text, 'lxml')
for each in soup.find_all(href=re.compile("topic")):
    print(each.text)
# Out:
# 话题
# 话题
#
# Python
# 12936 个问题
# 134107 个关注
#
# Python 入门
# 1955 个问题
# 14098 个关注
#
# Python 框架
# 627 个问题
# 5296 个关注
#
# Python 3.x
# 661 个问题
# 2248 个关注
#
# Python 开发
# 664 个问题
# 1329 个关注
#
# Python 库
# 240 个问题
# 1726 个关注
#
# Python教程
# 92 个问题
# 668 个关注
#
# Python 程序员
# 112 个问题
# 472 个关注
#
# Python 使用技巧
# 115 个问题
# 489 个关注
#
# Python IDE
# 73 个问题
# 449 个关注

# %%
from bs4 import BeautifulSoup
import requests

#url = 'https://s.taobao.com/search?ie=utf8&initiative_id=staobaoz_20170111&stats_click=search_radio_all%3A1&js=1&imgfile=&q=python%E6%95%99%E7%A8%8B&suggest=0_1&_input_charset=utf-8&wq=python&suggest_query=python&source=suggest'
url = 'https://www.taobao.com/markets/xie/xieqiangxin?spm=a21cx.8050146.587239.1.uUxBno&scm=1007.12013.16568.100000000000000'
headers = {'user-agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36'}
res = requests.get(url, headers=headers)
soup = BeautifulSoup(res.text, 'lxml')
#for item in soup.select('item J_MouserOnverReq'):
#    print(item.select('strong'))

print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>鞋抢新</title>
# <meta content="a21cx" name="spm-id"/>
# <meta content="" name="description"/>
# <meta content="" name="keyword"/>
# <link href="//g.alicdn.com/tbc/global/0.0.8/index-min.css" rel="stylesheet"/>
# <link href="//g.alicdn.com/tb-mod/??itemlist-first-screen/0.0.2/index.css,itemlist-for-qxofifashion/0.1.0/index.css" rel="stylesheet" type="text/css"/>
# <link href="https://g.alicdn.com/tms/layouts/0.1.8/layout-hangye-pc.css" rel="stylesheet"/>
# <script src="//g.alicdn.com/??kissy/k/1.4.16/seed-min.js,tms/tb-init/0.0.34/index-min.js,tbc/global/0.0.8/index-min.js,kg/kmd-adapter/0.1.5/index.js"></script>
# </head>
# <body data-spm="20121"><script>
# ...

# %%
#
